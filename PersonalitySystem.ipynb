# %% [markdown]
# ### Introduction
#
# ##### The objective of this project is to build a personality prediction system using the Big Five Personality Test dataset provided on Kaggle, collected (2016-2018) through an interactive on-line personality test. (Link: https://www.kaggle.com/datasets/tunguz/big-five-personality-test/data)
#
# ##### We aim to build a system to classify personality traits based on these user responses to the self-descriptive questions asked by the personality test.

# %% [markdown]
# 1. import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
# 2. read dataframe from file and display

# %%
df = pd.read_csv("../IPIP-FFM-data-8Nov2018/data-final.csv", delimiter = "\t")
df
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#                     dateload  screenw  screenh  introelapse  testelapse  \
# ...

# %% [markdown]
# 3. Explore dataframe

# %%
# Print columns
columns = df.columns
for column in columns:
    print(column)
# Out:
# EXT1
# EXT2
# EXT3
# EXT4
# EXT5
# EXT6
# EXT7
# EXT8
# EXT9
# EXT10
# EST1
# EST2
# EST3
# EST4
# EST5
# EST6
# EST7
# EST8
# EST9
# EST10
# AGR1
# AGR2
# AGR3
# AGR4
# AGR5
# AGR6
# AGR7
# AGR8
# AGR9
# AGR10
# CSN1
# CSN2
# CSN3
# CSN4
# CSN5
# CSN6
# CSN7
# CSN8
# CSN9
# CSN10
# OPN1
# OPN2
# OPN3
# OPN4
# OPN5
# OPN6
# OPN7
# OPN8
# OPN9
# OPN10
# EXT1_E
# EXT2_E
# EXT3_E
# EXT4_E
# EXT5_E
# EXT6_E
# EXT7_E
# EXT8_E
# EXT9_E
# EXT10_E
# EST1_E
# EST2_E
# EST3_E
# EST4_E
# EST5_E
# EST6_E
# EST7_E
# EST8_E
# EST9_E
# EST10_E
# AGR1_E
# AGR2_E
# AGR3_E
# AGR4_E
# AGR5_E
# AGR6_E
# AGR7_E
# AGR8_E
# AGR9_E
# AGR10_E
# CSN1_E
# CSN2_E
# CSN3_E
# CSN4_E
# CSN5_E
# CSN6_E
# CSN7_E
# CSN8_E
# CSN9_E
# CSN10_E
# OPN1_E
# OPN2_E
# OPN3_E
# OPN4_E
# OPN5_E
# OPN6_E
# OPN7_E
# OPN8_E
# OPN9_E
# OPN10_E
# dateload
# screenw
# screenh
# introelapse
# testelapse
# endelapse
# IPC
# country
# lat_appx_lots_of_err
# long_appx_lots_of_err

# %%
# Extract the first 50 columns 
x = df[df.columns[0:50]]
# Removes the limit of the number of columns shown
x
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#          OPN1  OPN2  OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# ...

# %% [markdown]
# 4. Check for missing values

# %%
# check whether x is a view or a copy
# print(x._is_view)

# %%
print("Missing value in data? ", "Yes" if x.isna().any().any() else "No")
# print(x.isna().any().any())

if (x.isna().any().any()):
    x = x.copy()
    x.fillna(0,inplace=True)
    print("Filling empty cells with 0...\n")

print("Missing data still exists." if x.isna().any().any() else "No missing data now! ")
# Out:
# Missing value in data?  Yes
# True
# Filling empty cells with 0...
#
# No missing data now!

# %% [markdown]
# 5. Initialize a MiniBatchKMeans clustering model, and fit it into x

# %%
kmeans = MiniBatchKMeans(n_clusters = 16, random_state = 0, batch_size = 100, max_iter=100, n_init='auto').fit(x)

# %%
# Check the number of cluster centers/personality types
len(kmeans.cluster_centers_)
# Out:
# 16

# %%
# Create a dictionary to map personality types to cluster centers
Pclusters = {f"Type {i+1}": center for i, center in enumerate(kmeans.cluster_centers_)}

# Access a specific cluster
print("Cluster for Type 1: \n\n", Pclusters["Type 1"])
# Out:
# Cluster for Type 1:
#
#  [2.76392588 2.76664662 3.37308474 2.91574305 3.37099407 2.11661941
#  2.80072744 3.13282928 3.52662027 3.32837873 1.97757539 3.87539021
#  2.71578314 3.36034024 2.06386574 1.81793969 2.13749749 1.71392159
#  2.62631383 1.89973365 3.44900765 3.06220466 3.071627   2.3304694
#  3.59294899 2.12028525 3.18933471 2.81046482 2.30987771 3.26591632
#  3.78993041 2.53925022 4.18269038 1.98920297 2.87307042 2.30990635
#  3.92361887 2.19469027 3.31128104 3.93083598 4.22539164 1.55070596
#  4.06758885 1.79267978 4.31222614 1.73935332 4.49674943 3.82893719
#  4.03594238 4.33121402]

# %%
# one_scores = {}
# one_scores["Extroversion_score"]=
Pclusters
# Out:
# {'Type 1': array([2.76392588, 2.76664662, 3.37308474, 2.91574305, 3.37099407,
#         2.11661941, 2.80072744, 3.13282928, 3.52662027, 3.32837873,
#         1.97757539, 3.87539021, 2.71578314, 3.36034024, 2.06386574,
#         1.81793969, 2.13749749, 1.71392159, 2.62631383, 1.89973365,
#         3.44900765, 3.06220466, 3.071627  , 2.3304694 , 3.59294899,
#         2.12028525, 3.18933471, 2.81046482, 2.30987771, 3.26591632,
#         3.78993041, 2.53925022, 4.18269038, 1.98920297, 2.87307042,
#         2.30990635, 3.92361887, 2.19469027, 3.31128104, 3.93083598,
#         4.22539164, 1.55070596, 4.06758885, 1.79267978, 4.31222614,
#         1.73935332, 4.49674943, 3.82893719, 4.03594238, 4.33121402]),
#  'Type 2': array([2.19401111, 3.18498929, 3.43227772, 3.52125736, 3.18199317,
#         2.62727638, 2.37538498, 4.03774438, 2.26447844, 3.98704472,
#         3.2342662 , 3.30545327, 4.02264663, 2.84927357, 2.52987748,
# ...
